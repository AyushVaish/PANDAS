# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 80.2MB/s]

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.shape
# Out:
# (1704, 6)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[0:4]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[0:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df.tail(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.iloc[-3:]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
print(df['year'])
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df.iloc[-3:]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df1 = pd.DataFrame({"name": ['tobey', 'peter', 'chris', 'pratt'],'chem_score':[10, 9, 8, 7], 'phy_score':[7, 8, 9, 10], 'Hindi_score':[9, 9, 9, 9]})
df2 = pd.DataFrame({"name": ['chris', 'pratt', 'andrew', 'tom'],'chem_score':[10, 10, 10, 9], 'maths_score':[6, 6, 7, 9], 'eng_score':[9, 10, 10, 9]})

# %%
print(df1)
# Out:
#     name  chem_score  phy_score  Hindi_score
# 0  tobey          10          7            9
# 1  peter           9          8            9
# 2  chris           8          9            9
# 3  pratt           7         10            9

# %%
print(df2)
# Out:
#      name  chem_score  maths_score  eng_score
# 0   chris          10            6          9
# 1   pratt          10            6         10
# 2  andrew          10            7         10
# 3     tom           9            9          9

# %%
x = pd.concat([df1,df2])
print(x)
# Out:
#      name  chem_score  phy_score  Hindi_score  maths_score  eng_score
# 0   tobey          10        7.0          9.0          NaN        NaN
# 1   peter           9        8.0          9.0          NaN        NaN
# 2   chris           8        9.0          9.0          NaN        NaN
# 3   pratt           7       10.0          9.0          NaN        NaN
# 0   chris          10        NaN          NaN          6.0        9.0
# 1   pratt          10        NaN          NaN          6.0       10.0
# 2  andrew          10        NaN          NaN          7.0       10.0
# 3     tom           9        NaN          NaN          9.0        9.0

# %%
x.iloc[[2,2,2,2]]
# Out:
#     name  chem_score  phy_score  Hindi_score  maths_score  eng_score
# 2  chris           8        9.0          9.0          NaN        NaN
# 2  chris           8        9.0          9.0          NaN        NaN
# 2  chris           8        9.0          9.0          NaN        NaN
# 2  chris           8        9.0          9.0          NaN        NaN

# %%
df.query('country == "Iceland" ')
# Out:
#      country  year  population continent  life_exp       gdp_cap
# 684  Iceland  1952      147962    Europe    72.490   7267.688428
# 685  Iceland  1957      165110    Europe    73.470   9244.001412
# 686  Iceland  1962      182053    Europe    73.680  10350.159060
# 687  Iceland  1967      198676    Europe    73.730  13319.895680
# 688  Iceland  1972      209275    Europe    74.460  15798.063620
# 689  Iceland  1977      221823    Europe    76.110  19654.962470
# 690  Iceland  1982      233997    Europe    76.990  23269.607500
# 691  Iceland  1987      244676    Europe    77.230  26923.206280
# 692  Iceland  1992      259012    Europe    78.770  25144.392010
# 693  Iceland  1997      271192    Europe    78.950  28061.099660
# 694  Iceland  2002      288030    Europe    80.500  31163.201960
# 695  Iceland  2007      301931    Europe    81.757  36180.789190

# %%
df3 = df.query('country == "Iceland" and year<2000')

df3["total_gdp"] = df3['population'] * df3['gdp_cap']
# Out:
# <ipython-input-24-d33cd37405a5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["total_gdp"] = df3['population'] * df3['gdp_cap']

# %%
df3
# Out:
#      country  year  population continent  life_exp       gdp_cap     total_gdp
# 684  Iceland  1952      147962    Europe     72.49   7267.688428  1.075342e+09
# 685  Iceland  1957      165110    Europe     73.47   9244.001412  1.526277e+09
# 686  Iceland  1962      182053    Europe     73.68  10350.159060  1.884278e+09
# 687  Iceland  1967      198676    Europe     73.73  13319.895680  2.646344e+09
# 688  Iceland  1972      209275    Europe     74.46  15798.063620  3.306140e+09
# 689  Iceland  1977      221823    Europe     76.11  19654.962470  4.359923e+09
# 690  Iceland  1982      233997    Europe     76.99  23269.607500  5.445018e+09
# 691  Iceland  1987      244676    Europe     77.23  26923.206280  6.587462e+09
# 692  Iceland  1992      259012    Europe     78.77  25144.392010  6.512699e+09
# 693  Iceland  1997      271192    Europe     78.95  28061.099660  7.609946e+09

# %%
aggr_list = ['sum','min','max','mean','count','median']
df3['total_gdp'].aggregate(aggr_list).astype(dtype = 'int64')
# Out:
# sum       40953428162
# min        1075341715
# max        7609945738
# mean       4095342816
# count              10
# median     3833031252
# Name: total_gdp, dtype: int64

# %%
df4 = df.sort_values(by="population",ascending=False).copy()
df4.drop_duplicates("continent",keep = 'first')
# Out:
#             country  year  population continent  life_exp       gdp_cap
# 299           China  2007  1318683096      Asia    72.961   4959.114854
# 1619  United States  2007   301139947  Americas    78.242  42951.653090
# 1139        Nigeria  2007   135031164    Africa    46.859   2013.977305
# 575         Germany  2007    82400996    Europe    79.406  32170.374420
# 71        Australia  2007    20434176   Oceania    81.235  34435.367440

# %%
df4 = df.sort_values(by="population",ascending=True).copy()
df4.drop_duplicates("continent",keep = 'first')
# Out:
#                     country  year  population continent  life_exp  \
# 1296  Sao Tome and Principe  1952       60011    Africa    46.471
# 84                  Bahrain  1952      120447      Asia    50.939
# 684                 Iceland  1952      147962    Europe    72.490
# 1548    Trinidad and Tobago  1952      662850  Americas    59.100
# 1092            New Zealand  1952     1994794   Oceania    69.390
#
#            gdp_cap
# 1296    879.583586
# 84     9867.084765
# 684    7267.688428
# 1548   3023.271928
# 1092  10556.575660

# %%
numerator = df.query('continent=="Asia" and year==1962 and life_exp>60').shape[0]
denominator = df.query('continent=="Asia" and year==1962').shape[0]
print(numerator / denominator *100)
# Out:
# 24.242424242424242

# %% [markdown]
# Concat and Merge

# %%
df1 = pd.DataFrame({"name": ['tobey', 'peter', 'chris', 'pratt'],'chem_score':[10, 9, 8, 7], 'phy_score':[7, 8, 9, 10], 'Hindi_score':[9, 9, 9, 9]})
df2 = pd.DataFrame({"name": ['chris', 'pratt', 'andrew', 'tom'],'chem_score':[10, 10, 10, 9], 'maths_score':[6, 6, 7, 9], 'eng_score':[9, 10, 10, 9]})

# %%
df1
# Out:
#     name  chem_score  phy_score  Hindi_score
# 0  tobey          10          7            9
# 1  peter           9          8            9
# 2  chris           8          9            9
# 3  pratt           7         10            9

# %%
df2
# Out:
#      name  chem_score  maths_score  eng_score
# 0   chris          10            6          9
# 1   pratt          10            6         10
# 2  andrew          10            7         10
# 3     tom           9            9          9

# %%
pd.concat([df1,df2])
# Out:
#      name  chem_score  phy_score  Hindi_score  maths_score  eng_score
# 0   tobey          10        7.0          9.0          NaN        NaN
# 1   peter           9        8.0          9.0          NaN        NaN
# 2   chris           8        9.0          9.0          NaN        NaN
# 3   pratt           7       10.0          9.0          NaN        NaN
# 0   chris          10        NaN          NaN          6.0        9.0
# 1   pratt          10        NaN          NaN          6.0       10.0
# 2  andrew          10        NaN          NaN          7.0       10.0
# 3     tom           9        NaN          NaN          9.0        9.0

# %%
pd.concat([df1,df2]).iloc[0].count()
# Out:
# 4

# %%
pd.concat([df1,df2]).count(axis =0)
# Out:
# name           8
# chem_score     8
# phy_score      4
# Hindi_score    4
# maths_score    4
# eng_score      4
# dtype: int64

# %%
pd.concat([df1,df2]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         8 non-null      object
#  1   chem_score   8 non-null      int64
#  2   phy_score    4 non-null      float64
#  3   Hindi_score  4 non-null      float64
#  4   maths_score  4 non-null      float64
#  5   eng_score    4 non-null      float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df1
# Out:
#     name  chem_score  phy_score  Hindi_score
# 0  tobey          10          7            9
# 1  peter           9          8            9
# 2  chris           8          9            9
# 3  pratt           7         10            9

# %%
df2
# Out:
#      name  chem_score  maths_score  eng_score
# 0   chris          10            6          9
# 1   pratt          10            6         10
# 2  andrew          10            7         10
# 3     tom           9            9          9

# %%
pd.merge(df1,df2,on='name',how='inner')
# Out:
#     name  chem_score_x  phy_score  Hindi_score  chem_score_y  maths_score  \
# 0  chris             8          9            9            10            6
# 1  pratt             7         10            9            10            6
#
#    eng_score
# 0          9
# 1         10

# %%
pd.merge(df1,df2,on='name',how='inner').mean(axis=1).iloc[0]
# Out:
# <ipython-input-39-fb37e6d069d6>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.merge(df1,df2,on='name',how='inner').mean(axis=1).iloc[0]
# 8.5
